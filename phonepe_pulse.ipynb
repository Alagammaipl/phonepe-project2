# %% [markdown]
# <a href="https://colab.research.google.com/github/Alagammaipl/phonepe-project2/blob/main/phonepe_pulse.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/PhonePe/pulse.git
# Out:
# fatal: destination path 'pulse' already exists and is not an empty directory.

# %% [markdown]
# Aggregated transactions statewise

# %%
#Once created the clone of GIT-HUB repository then,
#Required libraries for the program

import pandas as pd
import json
import os

#This is to direct the path to get the data as states

path="/content/pulse/data/aggregated/transaction/country/india/state/"
Agg_state_list=os.listdir(path)
Agg_state_list
#Agg_state_list--> to get the list of states in India

#<------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------>#

#This is to extract the data's to create a dataframe

clm={'State':[], 'Year':[],'Quater':[],'Transaction_type':[], 'Transaction_count':[], 'Transaction_amount':[]}
for i in Agg_state_list:
    a=path+i+"/"
    Agg_yr=os.listdir(a)    
    for j in Agg_yr:
        b=a+j+"/"
        Agg_yr_list=os.listdir(b)        
        for k in Agg_yr_list:
            c=b+k
            Data=open(c,'r')
            D=json.load(Data)
            for z in D['data']['transactionData']:
              Name=z['name']
              count=z['paymentInstruments'][0]['count']
              amount=z['paymentInstruments'][0]['amount']
              clm['Transaction_type'].append(Name)
              clm['Transaction_count'].append(count)
              clm['Transaction_amount'].append(amount)
              clm['State'].append(i)
              clm['Year'].append(j)
              clm['Quater'].append(int(k.strip('.json')))
#Succesfully created a dataframe
aggregated_transactions = pd.DataFrame(clm)
aggregated_transactions.head()
# Out:
#        State  Year  Quater          Transaction_type  Transaction_count  \
# 0  jharkhand  2021       3     Peer-to-peer payments           30113326
# 1  jharkhand  2021       3         Merchant payments           29687162
# 2  jharkhand  2021       3  Recharge & bill payments           10742405
# 3  jharkhand  2021       3        Financial Services              51289
# 4  jharkhand  2021       3                    Others             201520
#
#    Transaction_amount
# 0        9.774256e+10
# 1        1.995462e+10
# 2        4.029137e+09
# 3        6.503527e+07
# 4        9.966593e+07

# %%
aggtran =[(aggregated_transactions['Year'] == "2018") & (aggregated_transactions['Quater'] == "2")]
aggtran
# Out:
# [0       False
#  1       False
#  2       False
#  3       False
#  4       False
#          ...
#  3589    False
#  3590    False
#  3591    False
#  3592    False
#  3593    False
#  Length: 3594, dtype: bool]

# %%
aggregated_transactions['State'] = aggregated_transactions['State'].replace({'andaman-&-nicobar-islands': 'Andaman & Nicobar Island','andhra-pradesh':'Andhra Pradesh', 'arunachal-pradesh':'Arunachal Pradesh',
       'assam':'Assam', 'bihar':'Bihar', 'chandigarh':'Chandigarh', 'chhattisgarh':'Chhattisgarh',
       'dadra-&-nagar-haveli-&-daman-&-diu':'Dadra and Nagar Haveli and Daman and Diu', 'delhi': 'Delhi', 'goa':'Goa', 'gujarat': 'Gujarat',
       'haryana':'Haryana','himachal-pradesh':'Himachal Pradesh', 'jammu-&-kashmir':'Jammu & Kashmir', 'jharkhand':'Jharkhand',
       'karnataka':'Karnataka', 'kerala':'Kerala', 'ladakh':'Ladakh', 'lakshadweep':'Lakshadweep', 'madhya-pradesh':'Madhya Pradesh',
       'maharashtra':'Maharashtra', 'manipur':'Manipur', 'meghalaya':'Meghalaya', 'mizoram':'Mizoram', 'nagaland':'Nagaland',
       'odisha':'Odisha', 'puducherry':'Puducherry', 'punjab':'Punjab', 'rajasthan':'Rajasthan', 'sikkim':'Sikkim',
       'tamil-nadu': 'Tamil Nadu', 'telangana':'Telangana', 'tripura':'Tripura', 'uttar-pradesh':'Uttar Pradesh',
       'uttarakhand':'Uttarakhand', 'west-bengal':'West Bengal'})

# %%
a = aggregated_transactions[aggregated_transactions['Year'] == "2021"] 
b = a[a['Quater'] == 1 ]
b
c = b.Transaction_amount.sum()#total payment value
d = b.Transaction_count.sum()
e = c / d
e#avg transaction value
f = b.Transaction_count.sum()
f#no of transactions
# Out:
# 3457585463

# %%
aggregated_transactions.Transaction_type.unique()
# Out:
# array(['Peer-to-peer payments', 'Merchant payments',
#        'Recharge & bill payments', 'Financial Services', 'Others'],
#       dtype=object)

# %%
import pandas as pd
import plotly.express as px


fig = px.choropleth(
aggregated_transactions,
geojson="https://gist.githubusercontent.com/jbrobst/56c13bbbf9d97d187fea01ca62ea5112/raw/e388c4cae20aa53cb5090210a42ebb9b765c0a36/india_states.geojson",
featureidkey='properties.ST_NM',
locations='State',
color='Transaction_amount',
hover_data =['Transaction_count'],
projection="mercator",
color_continuous_scale='plasma'
)

fig.update_geos(fitbounds="locations", visible = False)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="c5715660-e584-4b78-acee-c2c945f317c6" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("c5715660-e584-4b78-acee-c2c945f317c6")) {                    Plotly.newPlot(                        "c5715660-e584-4b78-acee-c2c945f317c6",                        [{"coloraxis":"coloraxis","customdata":[[30113326],[29687162],[10742405],[51289],[201520],[19151083],[17489113],[7826608],[50526],[104333],[24184568],[19041292],[10583445],[54379],[138461],[45007900],[39476282],[11173974],[72802],[278084],[6003688],[1539476],[287427],[216343],[75687],[1095857],[809459],[107755],[66299],[99551],[1398777],[1375872],[160637],[130339],[86455],[3325473],[1885135],[845956],[136918],[90561],[5708187],[4766457],[3527625],[103620],[114758],[5952105],[2347079],[892826],[105558],[90140],[5155937],[2734377],[2049311],[67479],[121107],[10301226],[4390094],[3359590],[104630],[93078],[74816586],[57285937],[14462031],[68467],[182311],[53218047],[45881799],[11502811],[67502],[241051],[67435024],[52086790],[13145888],[50361],[207212],[91863987],[68045210],[15110623],[81074],[199198],[11984094],[7728846],[7211293],[56918],[87322],[8196850],[5454093],[4499942],[46483],[85345],[8724053],[7538593],[3753633],[56553],[68679],[17120664],[14168381],[7945996],[60989],[135603],[85074941],[83833356],[34751691],[182097],[515319],[57446279],[53811885],[24826273],[170620],[301617],[60812902],[52048347],[32753032],[192614],[351547],[117578360],[104493071],[36163870],[228761],[691914],[8810836],[5148411],[1290978],[191732],[332121],[3308548],[2670613],[326510],[115363],[305588],[4464677],[4433762],[627918],[167035],[298736],[11538547],[7093764],[3145621],[228398],[451114],[21277636],[10344027],[9246678],[88261],[453581],[18645926],[8863289],[4195222],[193261],[377347],[16952961],[8414514],[6296995],[70142],[437125],[28814008],[16153034],[11157765],[60624],[410980],[202149276],[148805657],[41919063],[217741],[404438],[139788772],[119383791],[34579431],[241201],[579955],[179245529],[136341691],[38257271],[202498],[459948],[229308285],[162920305],[43391904],[295740],[400402],[31754077],[20664887],[17521756],[129671],[207434],[30880360],[21541556],[14134259],[61427],[335871],[21700844],[18474731],[11477546],[78584],[138405],[47800741],[41297305],[21563946],[153044],[364665],[84353949],[58800005],[37556310],[189087],[813637],[53869075],[37143701],[26673733],[166727],[400816],[64661051],[41696787],[34799709],[190537],[549353],[105728377],[80248673],[37801439],[252535],[998536],[41882429],[7596315],[2252265],[1619524],[354883],[5773831],[4383075],[665171],[443378],[444770],[8284944],[7360522],[1121570],[937608],[377802],[17154995],[9425082],[8633569],[734796],[565106],[30804036],[21522913],[13011501],[558653],[547726],[27374206],[11659948],[7636726],[525650],[429858],[20285958],[13646142],[12129638],[421037],[540760],[67037576],[14511711],[14187744],[653648],[415159],[163523844],[145181044],[47208496],[238746],[640258],[124787028],[97315025],[37317865],[239530],[845644],[145395450],[126682135],[42712193],[191724],[760639],[184380244],[171667404],[48921147],[268388],[610414],[37556349],[22284079],[19599024],[151996],[363056],[28457404],[19779392],[17448908],[210068],[354609],[24855687],[22220012],[10225729],[130595],[244774],[46437233],[30077510],[23158305],[178455],[489142],[667633],[474693],[208387],[1437],[4642],[477346],[376473],[116846],[1511],[3721],[526966],[453979],[144413],[1624],[3809],[819452],[492411],[311673],[1790],[6157],[54885],[33930],[3518],[460],[1578],[28198],[11631],[822],[399],[1795],[41959],[20099],[1529],[379],[1633],[72881],[53723],[10350],[587],[1792],[145812],[100736],[13031],[210],[2089],[87596],[71642],[7306],[430],[1605],[92492],[81065],[12949],[286],[1961],[172761],[12 ...

# %% [markdown]
# Top transactions

# %%
#Once created the clone of GIT-HUB repository then,
#Required libraries for the program

import pandas as pd
import json
import os

#This is to direct the path to get the data as states

path="/content/pulse/data/top/transaction/country/india/state/"
Agg_state_list=os.listdir(path)
Agg_state_list
#Agg_state_list--> to get the list of states in India

#<------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------>#

#This is to extract the data's to create a dataframe

clm={'State':[], 'Year':[],'Quater':[],'district/pincode':[], 'count':[], 'Transaction_amount':[]}
for i in Agg_state_list:
    p_i=path+i+"/"
    Agg_yr=os.listdir(p_i)    
    for j in Agg_yr:
        p_j=p_i+j+"/"
        Agg_yr_list=os.listdir(p_j)        
        for k in Agg_yr_list:
            p_k=p_j+k
            Data=open(p_k,'r')
            D=json.load(Data)
            for z in D['data']['districts']:
              Name=z['entityName']
              count=z['metric']['count']
              amount=z['metric']['amount']
              clm['district/pincode'].append(Name)
              clm['count'].append(count)
              clm['Transaction_amount'].append(amount)
              clm['State'].append(i)
              clm['Year'].append(j)
              clm['Quater'].append(int(k.strip('.json')))
            for y in D['data']['pincodes']:
              Name=z['entityName']
              count=z['metric']['count']
              amount=z['metric']['amount']
              clm['district/pincode'].append(Name)
              clm['count'].append(count)
              clm['Transaction_amount'].append(amount)
              clm['State'].append(i)
              clm['Year'].append(j)
              clm['Quater'].append(int(k.strip('.json')))

#Succesfully created a dataframe
top_transactions = pd.DataFrame(clm)
top_transactions
# Out:
#                State  Year  Quater district/pincode     count  \
# 0          jharkhand  2021       3           ranchi  18164412
# 1          jharkhand  2021       3          dhanbad   7087770
# 2          jharkhand  2021       3           bokaro   6784128
# 3          jharkhand  2021       3   east singhbhum   6664581
# 4          jharkhand  2021       3       hazaribagh   5890582
# ...              ...   ...     ...              ...       ...
# 13054  uttar-pradesh  2020       4          aligarh   3179237
# 13055  uttar-pradesh  2020       4          aligarh   3179237
# 13056  uttar-pradesh  2020       4          aligarh   3179237
# 13057  uttar-pradesh  2020       4          aligarh   3179237
# 13058  uttar-pradesh  2020       4          aligarh   3179237
#
#        Transaction_amount
# 0            2.984067e+10
# 1            1.035866e+10
# 2            8.909128e+09
# 3            9.865148e+09
# 4            1.026070e+10
# ...                   ...
# 13054        6.659603e+09
# 13055        6.659603e+09
# 13056        6.659603e+09
# 13057        6.659603e+09
# 13058        6.659603e+09
#
# [13059 rows x 6 columns]

# %%
top_transactions['State'] = top_transactions['State'].replace({'andaman-&-nicobar-islands': 'Andaman & Nicobar Island','andhra-pradesh':'Andhra Pradesh', 'arunachal-pradesh':'Arunachal Pradesh',
       'assam':'Assam', 'bihar':'Bihar', 'chandigarh':'Chandigarh', 'chhattisgarh':'Chhattisgarh',
       'dadra-&-nagar-haveli-&-daman-&-diu':'Dadra and Nagar Haveli and Daman and Diu', 'delhi': 'Delhi', 'goa':'Goa', 'gujarat': 'Gujarat',
       'haryana':'Haryana','himachal-pradesh':'Himachal Pradesh', 'jammu-&-kashmir':'Jammu & Kashmir', 'jharkhand':'Jharkhand',
       'karnataka':'Karnataka', 'kerala':'Kerala', 'ladakh':'Ladakh', 'lakshadweep':'Lakshadweep', 'madhya-pradesh':'Madhya Pradesh',
       'maharashtra':'Maharashtra', 'manipur':'Manipur', 'meghalaya':'Meghalaya', 'mizoram':'Mizoram', 'nagaland':'Nagaland',
       'odisha':'Odisha', 'puducherry':'Puducherry', 'punjab':'Punjab', 'rajasthan':'Rajasthan', 'sikkim':'Sikkim',
       'tamil-nadu': 'Tamil Nadu', 'telangana':'Telangana', 'tripura':'Tripura', 'uttar-pradesh':'Uttar Pradesh',
       'uttarakhand':'Uttarakhand', 'west-bengal':'West Bengal'})

# %%
top_transactions['State'].unique()
# Out:
# array(['Jharkhand', 'Tamil Nadu', 'West Bengal', 'Nagaland', 'Gujarat',
#        'Telangana', 'Karnataka', 'Sikkim', 'Goa', 'Delhi', 'Haryana',
#        'Ladakh', 'Odisha', 'Lakshadweep', 'Maharashtra',
#        'Dadra and Nagar Haveli and Daman and Diu', 'Punjab', 'Puducherry',
#        'Tripura', 'Arunachal Pradesh', 'Manipur',
#        'Andaman & Nicobar Island', 'Himachal Pradesh', 'Madhya Pradesh',
#        'Mizoram', 'Kerala', 'Chhattisgarh', 'Chandigarh',
#        'Jammu & Kashmir', 'Meghalaya', 'Uttarakhand', 'Rajasthan',
#        'Bihar', 'Andhra Pradesh', 'Assam', 'Uttar Pradesh'], dtype=object)

# %% [markdown]
# map transactions

# %%
import pandas as pd
import json
import os

#This is to direct the path to get the data as states

path="/content/pulse/data/map/transaction/hover/country/india/state/"
Agg_state_list=os.listdir(path)
Agg_state_list
#Agg_state_list--> to get the list of states in India

#<------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------>#

#This is to extract the data's to create a dataframe

clm={'State':[], 'Year':[],'Quater':[],'district':[], 'count':[], 'Transaction_amount':[]}
for i in Agg_state_list:
    p_i=path+i+"/"
    Agg_yr=os.listdir(p_i)    
    for j in Agg_yr:
        p_j=p_i+j+"/"
        Agg_yr_list=os.listdir(p_j)        
        for k in Agg_yr_list:
            p_k=p_j+k
            Data=open(p_k,'r')
            D=json.load(Data)
            for z in D['data']['hoverDataList']:
              Name=z['name']
              count=z['metric'][0]['count']
              amount=z['metric'][0]['amount']
              clm['district'].append(Name)
              clm['count'].append(count)
              clm['Transaction_amount'].append(amount)
              clm['State'].append(i)
              clm['Year'].append(j)
              clm['Quater'].append(int(k.strip('.json')))

#Succesfully created a dataframe
map_transactions = pd.DataFrame(clm)
map_transactions
# Out:
#                State  Year  Quater                 district     count  \
# 0          jharkhand  2021       3         ramgarh district   2997440
# 1          jharkhand  2021       3          ranchi district  18164412
# 2          jharkhand  2021       3  east singhbhum district   6664581
# 3          jharkhand  2021       3         jamtara district    309392
# 4          jharkhand  2021       3           dumka district    738218
# ...              ...   ...     ...                      ...       ...
# 14631  uttar-pradesh  2020       4         kannauj district    639599
# 14632  uttar-pradesh  2020       4        azamgarh district   2036037
# 14633  uttar-pradesh  2020       4         ayodhya district   1547673
# 14634  uttar-pradesh  2020       4          deoria district   2392279
# 14635  uttar-pradesh  2020       4       ghaziabad district  15220234
#
#        Transaction_amount
# 0            4.729137e+09
# 1            2.984067e+10
# 2            9.865148e+09
# 3            6.488470e+08
# 4            1.457487e+09
# ...                   ...
# 14631        1.379451e+09
# 14632        4.814095e+09
# 14633        3.524811e+09
# 14634        5.497956e+09
# 14635        2.456535e+10
#
# [14636 rows x 6 columns]

# %%
map_transactions.shape
# Out:
# (14636, 6)

# %% [markdown]
# Top users

# %%
#Once created the clone of GIT-HUB repository then,
#Required libraries for the program

import pandas as pd
import json
import os

#This is to direct the path to get the data as states

path="/content/pulse/data/top/user/country/india/state/"
Agg_state_list=os.listdir(path)
Agg_state_list
#Agg_state_list--> to get the list of states in India

#<------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------>#

#This is to extract the data's to create a dataframe

clm={'State':[], 'Year':[],'Quater':[],'district/pincode':[], 'registered_users':[]}
for i in Agg_state_list:
    p_i=path+i+"/"
    Agg_yr=os.listdir(p_i)    
    for j in Agg_yr:
        p_j=p_i+j+"/"
        Agg_yr_list=os.listdir(p_j)        
        for k in Agg_yr_list:
            p_k=p_j+k
            Data=open(p_k,'r')
            D=json.load(Data)
            for z in D['data']['districts']:
              Name=z['name']
              registered_users=z['registeredUsers']
              clm['district/pincode'].append(Name)
              clm['registered_users'].append(registered_users)
              clm['State'].append(i)
              clm['Year'].append(j)
              clm['Quater'].append(int(k.strip('.json')))
            for y in D['data']['pincodes']:
              Name=z['name']
              registered_users=z['registeredUsers']
              clm['district/pincode'].append(Name)
              clm['registered_users'].append(registered_users)
              clm['State'].append(i)
              clm['Year'].append(j)
              clm['Quater'].append(int(k.strip('.json')))

#Succesfully created a dataframe
top_users = pd.DataFrame(clm)
top_users
# Out:
#                State  Year  Quater district/pincode  registered_users
# 0          jharkhand  2021       3           ranchi            982147
# 1          jharkhand  2021       3          dhanbad            759888
# 2          jharkhand  2021       3   east singhbhum            642805
# 3          jharkhand  2021       3           bokaro            551517
# 4          jharkhand  2021       3       hazaribagh            424328
# ...              ...   ...     ...              ...               ...
# 13055  uttar-pradesh  2020       4         bareilly            611236
# 13056  uttar-pradesh  2020       4         bareilly            611236
# 13057  uttar-pradesh  2020       4         bareilly            611236
# 13058  uttar-pradesh  2020       4         bareilly            611236
# 13059  uttar-pradesh  2020       4         bareilly            611236
#
# [13060 rows x 5 columns]

# %% [markdown]
# **Map Users**

# %%
#Once created the clone of GIT-HUB repository then,
#Required libraries for the program

import pandas as pd
import json
import os

#This is to direct the path to get the data as states

path="/content/pulse/data/map/user/hover/country/india/state/"
Agg_state_list=os.listdir(path)
Agg_state_list
#Agg_state_list--> to get the list of states in India

#<------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------>#

#This is to extract the data's to create a dataframe

clm={'State':[], 'Year':[],'Quater':[],'district':[], 'registered_users':[], 'appOpens' :[]}
for i in Agg_state_list:
    p_i=path+i+"/"
    Agg_yr=os.listdir(p_i)    
    for j in Agg_yr:
        p_j=p_i+j+"/"
        Agg_yr_list=os.listdir(p_j)        
        for k in Agg_yr_list:
            p_k=p_j+k
            Data=open(p_k,'r')
            D=json.load(Data)
            for z in D['data']['hoverData']:
              district = z
              registerdUsers = D['data']['hoverData'][z]['registeredUsers']
              appOpens = D['data']['hoverData'][z]['appOpens']
              clm['district'].append(district)
              clm['registered_users'].append(registerdUsers)
              clm['appOpens'].append(appOpens)
              clm['State'].append(i)
              clm['Year'].append(j)
              clm['Quater'].append(int(k.strip('.json')))
#Succesfully created a dataframe

map_users = pd.DataFrame(clm)
map_users
# Out:
#                State  Year  Quater                 district  registered_users  \
# 0          jharkhand  2021       3         ramgarh district            250016
# 1          jharkhand  2021       3          ranchi district            982147
# 2          jharkhand  2021       3  east singhbhum district            642805
# 3          jharkhand  2021       3         jamtara district            113199
# 4          jharkhand  2021       3           dumka district            124101
# ...              ...   ...     ...                      ...               ...
# 14635  uttar-pradesh  2020       4         kannauj district            156055
# 14636  uttar-pradesh  2020       4        azamgarh district            463173
# 14637  uttar-pradesh  2020       4         ayodhya district            296721
# 14638  uttar-pradesh  2020       4          deoria district            391411
# 14639  uttar-pradesh  2020       4       ghaziabad district           1647330
#
#        appOpens
# 0       8757056
# 1      27974257
# 2      16207989
# 3       2531677
# 4       5890404
# ...         ...
# 14635   2459812
# 14636   8312356
# 14637   5369147
# 14638   9021020
# 14639  41205756
#
# [14640 rows x 6 columns]

# %% [markdown]
# Aggregated users

# %%
import pandas as pd
import json
import os

#This is to direct the path to get the data as states

path="/content/pulse/data/aggregated/user/country/india/state/"
Agg_state_list=os.listdir(path)
Agg_state_list
#Agg_state_list--> to get the list of states in India

#<------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------>#

#This is to extract the data's to create a dataframe
x = []
clm={'State':[], 'Year':[],'Quater':[],'appOpens':[], 'registered_users':[]}
for i in Agg_state_list:
    p_i=path+i+"/"
    Agg_yr=os.listdir(p_i)    
    for j in Agg_yr:
        p_j=p_i+j+"/"
        Agg_yr_list=os.listdir(p_j)        
        for k in Agg_yr_list:
            p_k=p_j+k
            Data=open(p_k,'r')
            D=json.load(Data)
            for z in D['data']:
              registered_users= D['data']['aggregated']['registeredUsers']
              appOpens = D['data']['aggregated']['appOpens']
              #x.append(D['data']['usersByDevice'])
              clm['appOpens'].append(appOpens)
              clm['registered_users'].append(registered_users)
              clm['State'].append(i)
              clm['Year'].append(j)
              clm['Quater'].append(int(k.strip('.json')))

#Succesfully created a dataframe
agg_users = pd.DataFrame(clm)
agg_users
# Out:
#               State  Year  Quater   appOpens  registered_users
# 0         jharkhand  2021       3  230475998           6151843
# 1         jharkhand  2021       3  230475998           6151843
# 2         jharkhand  2021       1  141731331           5313049
# 3         jharkhand  2021       1  141731331           5313049
# 4         jharkhand  2021       2  184234107           5701503
# ...             ...   ...     ...        ...               ...
# 1435  uttar-pradesh  2020       1  374282083          20136256
# 1436  uttar-pradesh  2020       2  383703534          22498519
# 1437  uttar-pradesh  2020       2  383703534          22498519
# 1438  uttar-pradesh  2020       4  552220798          27249134
# 1439  uttar-pradesh  2020       4  552220798          27249134
#
# [1440 rows x 5 columns]

# %%
import pandas as pd
import json
import os

#This is to direct the path to get the data as states

path="/content/pulse/data/aggregated/user/country/india/state/"
Agg_state_list=os.listdir(path)
Agg_state_list
#Agg_state_list--> to get the list of states in India

#<------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------>#

#This is to extract the data's to create a dataframe
x = []
clm={'State':[], 'Year':[],'Quater':[], 'brand':[], 'count':[], 'percentage':[]}
for i in Agg_state_list:
    p_i=path+i+"/"
    Agg_yr=os.listdir(p_i)    
    for j in Agg_yr:
        p_j=p_i+j+"/"
        Agg_yr_list=os.listdir(p_j)        
        for k in Agg_yr_list:
            p_k=p_j+k
            Data=open(p_k,'r')
            D=json.load(Data)
            if D['data']['usersByDevice'] is None:
              continue

            for z in D['data']['usersByDevice']:
              brand= z['brand']
              count= z['count']
              percentage= z['percentage']
              clm['brand'].append(brand)
              clm['count'].append(count)
              clm['percentage'].append(percentage)
              clm['State'].append(i)
              clm['Year'].append(j)
              clm['Quater'].append(int(k.strip('.json')))

#Succesfully created a dataframe
agg_usersbydevice = pd.DataFrame(clm)
agg_usersbydevice
# Out:
#               State  Year  Quater     brand    count  percentage
# 0         jharkhand  2021       3    Xiaomi  1700564    0.276432
# 1         jharkhand  2021       3      Vivo  1106458    0.179858
# 2         jharkhand  2021       3   Samsung  1050011    0.170682
# 3         jharkhand  2021       3      Oppo   786674    0.127876
# 4         jharkhand  2021       3    Realme   657093    0.106812
# ...             ...   ...     ...       ...      ...         ...
# 6727  uttar-pradesh  2020       4     Apple   499152    0.018318
# 6728  uttar-pradesh  2020       4  Motorola   484675    0.017787
# 6729  uttar-pradesh  2020       4    Lenovo   348680    0.012796
# 6730  uttar-pradesh  2020       4      Lava   304244    0.011165
# 6731  uttar-pradesh  2020       4    Others  2795688    0.102597
#
# [6732 rows x 6 columns]

# %%
from sqlalchemy import create_engine

# %%
import sqlite3

conn = sqlite3.connect('my_database.db')

aggregated_transactions.to_sql('aggregated_transactions', conn, if_exists='replace', index=False)
map_transactions.to_sql('map_transactions', conn, if_exists='replace', index=False)
top_transactions.to_sql('top_transactions', conn, if_exists='replace', index=False)
map_users.to_sql('map_users', conn, if_exists='replace', index=False)
top_users.to_sql('top_users', conn, if_exists='replace', index=False)
agg_users.to_sql('agg_users',conn, if_exists='replace', index=False)
agg_usersbydevice.to_sql('agg_usersbydevice', conn, if_exists='replace', index=False)

conn.commit()

conn.close()

# %%
# !pip install -q streamlit
     

# !pip install streamlit -q
     

# !pip install pyngrok
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: pyngrok in /usr/local/lib/python3.8/dist-packages (5.2.1)
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.8/dist-packages (from pyngrok) (6.0)

# %%
from pyngrok import ngrok

# %%
ngrok.set_auth_token('2KlmmvWjpNy6q1qda2ek5eg1VDC_5jWpKTVMqurQ6yA68PHEx')
# Out:
# INFO:pyngrok.process:Updating authtoken for default "config_path" of "ngrok_path": /usr/local/lib/python3.8/dist-packages/pyngrok/bin/ngrok
# 2023-02-17 09:52:08.300 Updating authtoken for default "config_path" of "ngrok_path": /usr/local/lib/python3.8/dist-packages/pyngrok/bin/ngrok

# %%
# !nohup streamlit run app.py --server.port 80 &
# Out:
# nohup: appending output to 'nohup.out'

# %%
ngrok.connect(port = '8000')
# Out:
# INFO:pyngrok.ngrok:Opening tunnel named: http-80-87e09bdc-127a-493a-9b92-fa00222d3ec2
# 2023-02-17 09:52:13.879 Opening tunnel named: http-80-87e09bdc-127a-493a-9b92-fa00222d3ec2
# INFO:pyngrok.process.ngrok:t=2023-02-17T09:52:13+0000 lvl=info msg=start pg=/api/tunnels id=9909cbc4fe434fd9
# 2023-02-17 09:52:13.884 t=2023-02-17T09:52:13+0000 lvl=info msg=start pg=/api/tunnels id=9909cbc4fe434fd9
# WARNING:pyngrok.process.ngrok:t=2023-02-17T09:52:13+0000 lvl=warn msg="failed to start tunnel" pg=/api/tunnels id=9909cbc4fe434fd9 err=EOF
# 2023-02-17 09:52:13.958 t=2023-02-17T09:52:13+0000 lvl=warn msg="failed to start tunnel" pg=/api/tunnels id=9909cbc4fe434fd9 err=EOF
# INFO:pyngrok.process.ngrok:t=2023-02-17T09:52:13+0000 lvl=info msg=end pg=/api/tunnels id=9909cbc4fe434fd9 status=502 dur=74.230603ms
# 2023-02-17 09:52:13.970 t=2023-02-17T09:52:13+0000 lvl=info msg=end pg=/api/tunnels id=9909cbc4fe434fd9 status=502 dur=74.230603ms
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# /usr/local/lib/python3.8/dist-packages/pyngrok/ngrok.py in api_request(url, method, data, params, timeout)
#     455     try:
# --> 456         response = urlopen(request, data, timeout)
#     457         response_data = response.read().decode("utf-8")
#
# /usr/lib/python3.8/urllib/request.py in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     221         opener = _opener
# --> 222     return opener.open(url, data, timeout)
#     223
#
# /usr/lib/python3.8/urllib/request.py in open(self, fullurl, data, timeout)
#     530             meth = getattr(processor, meth_name)
# --> 531             response = meth(req, response)
#     532
#
# /usr/lib/python3.8/urllib/request.py in http_response(self, request, response)
#     639         if not (200 <= code < 300):
# --> 640             response = self.parent.error(
#     641                 'http', request, response, code, msg, hdrs)
#
# /usr/lib/python3.8/urllib/request.py in error(self, proto, *args)
#     568             args = (dict, 'default', 'http_error_default') + orig_args
# --> 569             return self._call_chain(*args)
#     570
#
# /usr/lib/python3.8/urllib/request.py in _call_chain(self, chain, kind, meth_name, *args)
#     501             func = getattr(handler, meth_name)
# --> 502             result = func(*args)
#     503             if result is not None:
#
# /usr/lib/python3.8/urllib/request.py in http_error_default(self, req, fp, code, msg, hdrs)
#     648     def http_error_default(self, req, fp, code, msg, hdrs):
# --> 649         raise HTTPError(req.full_url, code, msg, hdrs, fp)
#     650
#
# HTTPError: HTTP Error 502: Bad Gateway
#
# During handling of the above exception, another exception occurred:
#
# PyngrokNgrokHTTPError                     Traceback (most recent call last)
# <ipython-input-231-6d0e0a77ee74> in <module>
# ----> 1 ngrok.connect(port = '8000')
#       2
#
# /usr/local/lib/python3.8/dist-packages/pyngrok/ngrok.py in connect(addr, proto, name, pyngrok_config, **options)
#     269     logger.debug("Creating tunnel with options: {}".format(options))
#     270
# --> 271     tunnel = NgrokTunnel(api_request("{}/api/tunnels".format(api_url), method="POST", data=options,
#     272                                      timeout=pyngrok_config.request_timeout),
#     273                          pyngrok_config, api_url)
#
# /usr/local/lib/python3.8/dist-packages/pyngrok/ngrok.py in api_request(url, method, data, params, timeout)
#     475         logger.debug("Response {}: {}".format(status_code, response_data.strip()))
#     476
# --> 477         raise PyngrokNgrokHTTPError("ngrok client exception, API returned {}: {}".format(status_code, response_data),
#     478                                     e.url,
#     479                                     status_code, e.msg, e.hdrs, response_data)
#
# PyngrokNgrokHTTPError: ngrok client exception, API returned 502: {"error_code":103,"status_code":502,"msg":"failed to start tunnel","details":{"err":"EOF"}}

# %%
#%%writefile app.py
#importing needed modules

import streamlit as st
import numpy as np
import pandas as pd
import json
import sqlite3
import plotly.express as px

#establishing sql connection
conn = sqlite3.connect('my_database.db')

#extracting data from mysql database

aggregated_transactions = pd.read_sql_query("select * FROM aggregated_transactions", conn)
top_transactions = pd.read_sql_query("select * FROM top_transactions", conn)
map_users = pd.read_sql_query("select * FROM map_users", conn)
top_users = pd.read_sql_query("select * FROM top_users", conn)
agg_users = pd.read_sql_query("select * FROM agg_users", conn)
agg_usersbydevice = pd.read_sql_query("select * FROM agg_usersbydevice", conn)
conn.commit()

#creating heading
st.title("PhonePe Pulse Data Visualization")

st.sidebar.title("filters")
x = st.selectbox("All India or Statewise", ("All india", "Statewise"))
a = st.sidebar.selectbox('Select transactions or users', ('Transactions', 'Users'))
b = st.sidebar.selectbox('year', ('2018', '2019', '2020', '2021', '2022'))
c = st.sidebar.selectbox('Quartile', ('1', '2', '3', '4'))

if x == "All india":
  if a == "Transactions":
   #if b == "2018":
     #if c =='1':
    aggtran =aggregated_transactions[aggregated_transactions['Year'] == b]
    aggtrans = aggtran[aggtran['Quater'] == int(c)]
    st.write("Total transactions", aggtrans.Transaction_count.sum())
    st.write("Total payment", aggtrans.Transaction_amount.sum())
    st.write("Avg payment per transaction",aggtrans.Transaction_amount.sum()/aggtrans.Transaction_count.sum())
    droped = aggtrans.drop(['Quater','Year', 'State'], axis=1)
    e = aggtrans.Transaction_type.unique()
    for i in range (len(e)):
        u = aggtrans[aggtrans['Transaction_type'] == e[i]]
        st.write(e[i], u.Transaction_count.sum())

        
         
      
    st.write(droped)
    fig = px.choropleth(
aggtrans,
geojson="https://gist.githubusercontent.com/jbrobst/56c13bbbf9d97d187fea01ca62ea5112/raw/e388c4cae20aa53cb5090210a42ebb9b765c0a36/india_states.geojson",
featureidkey='properties.ST_NM',
locations='State',
color='Transaction_amount',
hover_data =['Transaction_count', 'State'],
projection="mercator",
color_continuous_scale='plotly3'
)
    fig.update_geos(fitbounds="locations", visible = False)
    st.plotly_chart(fig, theme = "streamlit")


if x == "Statewise":
  st.sidebar.selectbox("Select a state", ['Jharkhand', 'Tamil Nadu', 'West Bengal', 'Nagaland', 'Gujarat',
       'Telangana', 'Karnataka', 'Sikkim', 'Goa', 'Delhi', 'Haryana',
       'Ladakh', 'Odisha', 'Lakshadweep', 'Maharashtra',
       'Dadra and Nagar Haveli and Daman and Diu', 'Punjab', 'Puducherry',
       'Tripura', 'Arunachal Pradesh', 'Manipur',
       'Andaman & Nicobar Island', 'Himachal Pradesh', 'Madhya Pradesh',
       'Mizoram', 'Kerala', 'Chhattisgarh', 'Chandigarh',
       'Jammu & Kashmir', 'Meghalaya', 'Uttarakhand', 'Rajasthan',
       'Bihar', 'Andhra Pradesh', 'Assam', 'Uttar Pradesh'])
